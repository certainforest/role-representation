# %% [markdown]
# ## Motivation + Research Questions
#
# We test whether speaker identity is encoded as a structured role signal rather than as a superficial cue from explicit tags. If role binding is present, we should see a stable role direction in activation space, and causal interventions on identity cues should change speaker separation.
#
# **RQs**
# - **RQ1 (Representation):** Are speaker roles separable in activation space without explicit `Alice:`/`Bob:` tags?
# - **RQ2 (Structure):** Is there a stable role direction that generalizes across turns/layers?
# - **RQ3 (Causality):** Are early identity cues (name mentions) causally responsible for speaker separation?

# %%
# !pip install -U "transformers>=4.40.0" "accelerate>=0.30.0"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 4.5 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 553.2/553.2 kB 3.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 4.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 kB 614.5 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 3.7 MB/s eta 0:00:0000:0100:01
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 4.2.0 requires fsspec[http]<=2025.9.0,>=2023.1.0, but you have fsspec 2025.10.0 which is incompatible.
# fastembed 0.7.3 requires huggingface-hub<1.0,>=0.20, but you have huggingface-hub 1.4.0 which is incompatible.
# ...

# %%
# Core imports
import os
import re
import numpy as np
import torch
import matplotlib.pyplot as plt

from sklearn.decomposition import PCA

# Fix cluster home quota: redirect caches (edit path if needed)
os.environ.setdefault("ROLE_REP_CACHE_DIR", f"/scratch/fernando.je/role-rep")
os.environ.setdefault("HF_HOME", os.path.join(os.environ["ROLE_REP_CACHE_DIR"], "hf"))
os.environ.setdefault("HUGGINGFACE_HUB_CACHE", os.path.join(os.environ["HF_HOME"], "hub"))
os.environ.setdefault("TRANSFORMERS_CACHE", os.path.join(os.environ["HF_HOME"], "transformers"))
os.environ.setdefault("TORCH_HOME", os.path.join(os.environ["ROLE_REP_CACHE_DIR"], "torch"))
os.environ.setdefault("XDG_CACHE_HOME", os.path.join(os.environ["ROLE_REP_CACHE_DIR"], "xdg"))

for path in [
    os.environ["ROLE_REP_CACHE_DIR"],
    os.environ["HF_HOME"],
    os.environ["HUGGINGFACE_HUB_CACHE"],
    os.environ["TRANSFORMERS_CACHE"],
    os.environ["TORCH_HOME"],
    os.environ["XDG_CACHE_HOME"],
]:
    os.makedirs(path, exist_ok=True)

# Avoid widget/progress-bar issues + HF xet
os.environ["HF_HUB_DISABLE_PROGRESS_BARS"] = "1"
os.environ["DISABLE_TQDM"] = "1"
os.environ["HF_HUB_DISABLE_XET"] = "1"

from transformers import AutoTokenizer, AutoModelForCausalLM

np.random.seed(7)
torch.manual_seed(7)

device = "cuda" if torch.cuda.is_available() else "cpu"
print("device:", device)
# Out:
# device: cpu

# %%
# Optional one-time cleanup of old OOD session cache in $HOME
# Comment out if you don't want automatic deletes.
import shutil
import glob

ood_cache = os.path.expanduser("~/ondemand/data/sys/dashboard/batch_connect")
if os.path.isdir(ood_cache):
    # Remove completed session dirs (keeps the parent folder)
    for path in glob.glob(os.path.join(ood_cache, "*")):
        try:
            shutil.rmtree(path)
        except Exception:
            pass

print("ROLE_REP_CACHE_DIR:", os.environ.get("ROLE_REP_CACHE_DIR"))
print("HF_HOME:", os.environ.get("HF_HOME"))

# %%
# Optional dependency check (avoid installing into /home on clusters)
import importlib.util
print("accelerate available:", importlib.util.find_spec("accelerate") is not None)

import getpass
if not (os.environ.get("HF_TOKEN") or os.environ.get("HUGGINGFACE_HUB_TOKEN")):
    os.environ["HF_TOKEN"] = getpass.getpass("HF token: ")
    os.environ["HUGGINGFACE_HUB_TOKEN"] = os.environ["HF_TOKEN"]

if not os.environ.get("NDIF_API_KEY"):
    os.environ["NDIF_API_KEY"] = getpass.getpass("NDIF API key: ")
# Out:
# accelerate available: True

# %%
# Two-speaker multi-turn transcript (edit freely)
# No explicit "Alice:"/"Bob:" tags; names appear in early lines.
TRANSCRIPT_TURNS = [
    "Hey Bob, before we jump in, I wanted to revisit the design proposal.",
    "Sure, Alice, I skimmed it last night; the latency targets look ambitious.",
    "The client asked for sub-200ms p95; I think batching can get us there.",
    "Batching helps, but the cache invalidation could become tricky.",
    "We can constrain invalidation to product-level keys instead of per-user.",
    "That might reduce precision, though; would that impact personalization?",
    "Some, but we can re-rank on the client side for the top 10 results.",
    "Okay, so you are proposing a hybrid: coarse cache, fine rerank.",
    "Exactly. And we should log enough to measure drift each week.",
    "Logging is fine, but data retention policy caps at 30 days.",
    "Right, I can summarize weekly aggregates and delete raw events.",
    "Great. Also, the new API endpoint needs a version bump.",
    "v3 seems reasonable; we can keep v2 for a deprecation window.",
    "Then we need a migration guide; I can draft it.",
    "Thanks. Another point: the search index rebuild takes 6 hours.",
    "Maybe we can parallelize by shard and compress the postings lists.",
    "If we compress too much, we might slow decoding at query time.",
    "True; we could trade storage for CPU if latency budget allows.",
    "We'll benchmark both. Also, what about adding synonyms?",
    "Synonyms help recall, but they increase false positives.",
    "We'll tune the threshold and evaluate per-category.",
    "Sounds good. On another note, QA reported flaky tests.",
    "I saw that; I think the mock clock isn't resetting in CI.",
    "I can isolate those tests and add a fixture.",
    "Appreciate it. Lastly, are we aligned on the rollout plan?",
    "Staged rollout: internal, then 5% external, then 50%.",
    "And we monitor error rates and rollback if p95 spikes.",
    "Yes. I'll write the runbook.",
    "Great, I'll update the proposal and send it today.",
    "Perfect; I will review as soon as it lands.",
    "Thanks, Bob.",
    "Thanks, Alice.",
]

# Ground-truth speaker for each turn (assumes strict alternation)
TURN_SPEAKERS = ["Alice" if i % 2 == 0 else "Bob" for i in range(len(TRANSCRIPT_TURNS))]

FULL_TEXT = "\n".join(TRANSCRIPT_TURNS)

# %%
# Model load (supports HF and NDIF)
from transformers import AutoConfig

MODEL_SOURCE = os.environ.get("MODEL_SOURCE", "hf").lower()
DEFAULT_MODEL_ID = "meta-llama/Meta-Llama-3.1-8B"

if MODEL_SOURCE == "ndif":
    MODEL_ID = os.environ.get("NDIF_MODEL_ID", DEFAULT_MODEL_ID)
    AUTH_TOKEN = os.environ.get("NDIF_API_KEY")
else:
    MODEL_ID = os.environ.get("HF_MODEL_ID", DEFAULT_MODEL_ID)
    AUTH_TOKEN = os.environ.get("HF_TOKEN") or os.environ.get("HUGGINGFACE_HUB_TOKEN")

cache_dir = os.environ.get("HUGGINGFACE_HUB_CACHE")

tokenizer = AutoTokenizer.from_pretrained(MODEL_ID, cache_dir=cache_dir, token=AUTH_TOKEN)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

dtype = torch.bfloat16 if device == "cuda" else torch.float32

# Workaround for older Transformers that expect rope_scaling = {type, factor}
config = AutoConfig.from_pretrained(MODEL_ID, cache_dir=cache_dir, token=AUTH_TOKEN)
if isinstance(getattr(config, "rope_scaling", None), dict):
    rs = config.rope_scaling
    if "type" not in rs or "factor" not in rs or len(rs) != 2:
        config.rope_scaling = {"type": "linear", "factor": float(rs.get("factor", 1.0))}

model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    config=config,
    torch_dtype=dtype,
    device_map="auto" if device == "cuda" else None,
    cache_dir=cache_dir,
    token=AUTH_TOKEN,
)

# If special tokens were added, resize embeddings
if len(tokenizer) > model.get_input_embeddings().num_embeddings:
    model.resize_token_embeddings(len(tokenizer))

model.eval()
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 6
#       4 tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
#       5 dtype = torch.bfloat16 if device == "cuda" else torch.float32
# ----> 6 model = AutoModelForCausalLM.from_pretrained(
#       7     MODEL_ID,
#       8     torch_dtype=dtype,
#       9     device_map="auto" if device == "cuda" else None,
#      10 )
#      11 model.eval()
#
# File /shared/EL9/explorer/anaconda3/2024.06/lib/python3.12/site-packages/transformers/models/auto/auto_factory.py:524, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     521 if kwargs.get("quantization_config", None) is not None:
#     522     _ = kwargs.pop("quantization_config")
# ...

# %%
def parse_turns(turns, turn_speakers):
    """Return per-turn offsets and speaker labels for a turn list."""
    out = []
    cursor = 0
    for i, line in enumerate(turns):
        line_start = cursor
        line_end = cursor + len(line)
        speaker = turn_speakers[i] if i < len(turn_speakers) else "UNKNOWN"
        out.append(
            {
                "speaker": speaker,
                "line_start": line_start,
                "line_end": line_end,
+                "content_start": line_start,
            }
        )
        cursor = line_end + 1
    return out


def tokenize_with_offsets(text):
    enc = tokenizer(
        text,
        return_offsets_mapping=True,
        add_special_tokens=False,
    )
    input_ids = torch.tensor([enc["input_ids"]])
    offsets = enc["offset_mapping"]
    return input_ids, offsets


def label_tokens_by_turn(offsets, turns):
    token_turn_idx = []
    turn_idx = 0
    for start, end in offsets:
        while turn_idx < len(turns) and start >= turns[turn_idx]["line_end"]:
            turn_idx += 1
        if turn_idx >= len(turns):
            token_turn_idx.append(None)
        else:
            token_turn_idx.append(turn_idx)
    token_speakers = [turns[i]["speaker"] if i is not None else "UNKNOWN" for i in token_turn_idx]
    return token_turn_idx, token_speakers


@torch.no_grad()
def extract_hidden_states(text):
    input_ids, offsets = tokenize_with_offsets(text)
    input_ids = input_ids.to(model.device)
    outputs = model(input_ids, output_hidden_states=True)
    # hidden_states: tuple (embeddings + each layer)
    hidden_states = [hs[0].float().cpu().numpy() for hs in outputs.hidden_states]
    return hidden_states, offsets

# %%
# Extract activations for the main transcript
turns = parse_turns(TRANSCRIPT_TURNS, TURN_SPEAKERS)
hidden_states, offsets = extract_hidden_states(FULL_TEXT)
token_turn_idx, token_speakers = label_tokens_by_turn(offsets, turns)

print("tokens:", len(token_speakers), "layers:", len(hidden_states))

# %% [markdown]
# ## Experiment: Role difference vectors
#
# **What it tests:** a candidate role axis computed as mean(Alice) − mean(Bob) per layer.
#
# **RQ coverage:** RQ1 (separability) and RQ2 (stability across layers).

# %%
# Role difference vectors per layer (mean Alice minus mean Bob)
def compute_role_diff_vectors(hidden_states, token_speakers):
    role_diffs = []
    for hs in hidden_states:
        hs = np.asarray(hs)
        mask_a = np.array([s == "Alice" for s in token_speakers])
        mask_b = np.array([s == "Bob" for s in token_speakers])
        mean_a = hs[mask_a].mean(axis=0)
        mean_b = hs[mask_b].mean(axis=0)
        role_diffs.append(mean_a - mean_b)
    return role_diffs


role_diffs = compute_role_diff_vectors(hidden_states, token_speakers)
role_norms = [np.linalg.norm(v) for v in role_diffs]

plt.figure(figsize=(6, 3))
plt.plot(role_norms, marker="o")
plt.title("Role diff norm by layer")
plt.xlabel("Layer (0 = embeddings)")
plt.ylabel("L2 norm")
plt.show()

# %% [markdown]
# ## Experiment: PCA on raw vs speaker-centered activations
#
# **What it tests:** whether speaker separation dominates raw activations and whether centering by speaker reveals content structure.
#
# **RQ coverage:** RQ1 (separability without tags) and RQ2 (role/filler factorization).

# %%
# PCA on speaker-centered activations (choose a layer)
LAYER_FOR_PCA = -1

hs = np.asarray(hidden_states[LAYER_FOR_PCA])
mask_a = np.array([s == "Alice" for s in token_speakers])
mask_b = np.array([s == "Bob" for s in token_speakers])

mean_a = hs[mask_a].mean(axis=0)
mean_b = hs[mask_b].mean(axis=0)

# Speaker-centered
hs_centered = hs.copy()
hs_centered[mask_a] -= mean_a
hs_centered[mask_b] -= mean_b

pca = PCA(n_components=2)
proj_raw = pca.fit_transform(hs)

pca_centered = PCA(n_components=2)
proj_centered = pca_centered.fit_transform(hs_centered)

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.scatter(proj_raw[:, 0], proj_raw[:, 1], c=mask_a, s=8, alpha=0.6)
plt.title("PCA (raw)")

plt.subplot(1, 2, 2)
plt.scatter(proj_centered[:, 0], proj_centered[:, 1], c=mask_a, s=8, alpha=0.6)
plt.title("PCA (speaker-centered)")
plt.show()

print("Raw PCA explained variance:", pca.explained_variance_ratio_)
print("Centered PCA explained variance:", pca_centered.explained_variance_ratio_)

# %% [markdown]
# ## Experiment: Name-swap test (intro lines)
#
# **What it tests:** whether the role axis tracks explicit identity cues (names) when content is fixed.
#
# **RQ coverage:** RQ3 (causality of identity cues).

# %%
# Swap test: swap the *names* inside the first two intro lines
# This tests sensitivity to explicit identity cues without using "Alice:"/"Bob:" tags.

def swap_names_in_intro(turns):
    swapped = list(turns)
    if len(swapped) >= 2:
        for i in (0, 1):
            tmp = swapped[i].replace("Alice", "__TEMP__")
            tmp = tmp.replace("Bob", "Alice")
            swapped[i] = tmp.replace("__TEMP__", "Bob")
    return swapped


SWAPPED_TURNS = swap_names_in_intro(TRANSCRIPT_TURNS)
SWAPPED_TEXT = "\n".join(SWAPPED_TURNS)

# Role vector from original transcript (use chosen layer)
layer_idx = LAYER_FOR_PCA
role_vec = role_diffs[layer_idx]
role_vec = role_vec / (np.linalg.norm(role_vec) + 1e-8)

# Hidden states for swapped-intro transcript
swapped_turns = parse_turns(SWAPPED_TURNS, TURN_SPEAKERS)
swapped_states, swapped_offsets = extract_hidden_states(SWAPPED_TEXT)
_, swapped_speakers = label_tokens_by_turn(swapped_offsets, swapped_turns)

# Content speakers come from original turn order
content_speakers = [turns[i]["speaker"] if i is not None else "UNKNOWN" for i in token_turn_idx]

swapped_hs = np.asarray(swapped_states[layer_idx])
proj_swapped = swapped_hs @ role_vec

def mean_projection_by_label(proj, labels, label_name):
    labels = np.array(labels)
    mean_a = proj[labels == "Alice"].mean()
    mean_b = proj[labels == "Bob"].mean()
    print(f"{label_name} mean projection - Alice: {mean_a:.4f}, Bob: {mean_b:.4f}")


mean_projection_by_label(proj_swapped, swapped_speakers, "Swapped intro (true labels)")
mean_projection_by_label(proj_swapped, content_speakers, "Original labels")

# %% [markdown]
# ## Activation patching + causal localization
#
# This section patches speaker-name activations from a *donor* transcript into the base transcript,
# then measures how much the speaker separation changes. We also sweep layers to localize the effect.

# %%
def get_decoder_layers(model):
    if hasattr(model, "model") and hasattr(model.model, "layers"):
        return model.model.layers
    if hasattr(model, "base_model") and hasattr(model.base_model, "model") and hasattr(model.base_model.model, "layers"):
        return model.base_model.model.layers
    raise AttributeError("Could not find decoder layers on this model")


def find_subsequence_positions(sequence, pattern):
    if not pattern or len(pattern) > len(sequence):
        return []
    out = []
    m = len(pattern)
    for i in range(len(sequence) - m + 1):
        if sequence[i : i + m] == pattern:
            out.append(i)
    return out


def find_name_positions(text, name, max_hits=1):
    ids = tokenizer(text, add_special_tokens=False).input_ids
    patterns = [
        tokenizer.encode(name, add_special_tokens=False),
        tokenizer.encode(" " + name, add_special_tokens=False),
    ]
    hits = []
    for pat in patterns:
        hits.extend(find_subsequence_positions(ids, pat))
    hits = sorted(list(dict.fromkeys(hits)))
    return hits[:max_hits]


def role_projection_gap(hidden_states, token_speakers, hs_index, role_vec):
    hs = np.asarray(hidden_states[hs_index])
    proj = hs @ role_vec
    mask_a = np.array([s == "Alice" for s in token_speakers])
    mask_b = np.array([s == "Bob" for s in token_speakers])
    return proj[mask_a].mean() - proj[mask_b].mean()


def run_with_patch(text, layer_idx, patch_positions, patch_vectors):
    """Patch specified token positions at a given decoder layer.

    layer_idx refers to the decoder layer index (0-based).
    patch_positions is a list of token indices in the *base* text.
    patch_vectors is a list of vectors aligned with patch_positions.
    """
    input_ids, offsets = tokenize_with_offsets(text)
    input_ids = input_ids.to(model.device)

    layers = get_decoder_layers(model)
    layer = layers[layer_idx]

    model_dtype = next(model.parameters()).dtype
    patch_tensors = [
        torch.tensor(vec, device=model.device, dtype=model_dtype)
        for vec in patch_vectors
    ]

    def hook_fn(_module, _inputs, output):
        hs = output[0] if isinstance(output, tuple) else output
        hs = hs.clone()
        for pos, vec in zip(patch_positions, patch_tensors):
            if pos < hs.shape[1]:
                hs[:, pos, :] = vec
        if isinstance(output, tuple):
            return (hs,) + output[1:]
        return hs

    handle = layer.register_forward_hook(hook_fn)
    with torch.no_grad():
        outputs = model(input_ids, output_hidden_states=True)
    handle.remove()

    hidden_states = [hs[0].float().cpu().numpy() for hs in outputs.hidden_states]
    return hidden_states, offsets


def corrupt_intro_names(turns, mode="mask"):
    """Corrupt names only in the first two turns."""
    out = list(turns)
    if len(out) < 2:
        return out

    if mode == "swap":
        for i in (0, 1):
            tmp = out[i].replace("Alice", "__TEMP__")
            tmp = tmp.replace("Bob", "Alice")
            out[i] = tmp.replace("__TEMP__", "Bob")
        return out

    if mode == "mask":
        for i in (0, 1):
            out[i] = out[i].replace("Alice", "Speaker").replace("Bob", "Speaker")
        return out

    if mode == "random":
        for i in (0, 1):
            out[i] = out[i].replace("Alice", "Casey").replace("Bob", "Jordan")
        return out

    return out

# %%
BASE_TEXT = FULL_TEXT
DONOR_TEXTS = {
    "swap_intro": "\n".join(corrupt_intro_names(TRANSCRIPT_TURNS, mode="swap")),
    "mask_intro": "\n".join(corrupt_intro_names(TRANSCRIPT_TURNS, mode="mask")),
    "random_intro": "\n".join(corrupt_intro_names(TRANSCRIPT_TURNS, mode="random")),
}
NAME_TARGETS = ["Alice", "Bob"]

base_name_positions = {name: find_name_positions(BASE_TEXT, name, max_hits=1) for name in NAME_TARGETS}

role_vecs = []
for v in role_diffs:
    n = np.linalg.norm(v) + 1e-8
    role_vecs.append(v / n)


def compute_donor_vectors(text, layer_idx):
    hs, _ = extract_hidden_states(text)
    hs_index = layer_idx + 1
    vecs = {}
    for name in NAME_TARGETS:
        donor_pos = find_name_positions(text, name, max_hits=1)
        if not donor_pos:
            raise ValueError(f"No '{name}' token positions found in donor text")
        vecs[name] = np.asarray(hs[hs_index])[donor_pos].mean(axis=0)
    return vecs


def run_patch_eval(donor_text, layer_idx):
    hs_index = layer_idx + 1
    donor_vecs = compute_donor_vectors(donor_text, layer_idx)

    patch_positions = []
    patch_vectors = []
    for name in NAME_TARGETS:
        if base_name_positions[name]:
            patch_positions.append(base_name_positions[name][0])
            patch_vectors.append(donor_vecs[name])

    if not patch_positions:
        raise ValueError("No base name positions found to patch")

    patched_hs, _ = run_with_patch(BASE_TEXT, layer_idx, patch_positions, patch_vectors)

    base_gap = role_projection_gap(hidden_states, token_speakers, hs_index, role_vecs[hs_index])
    patched_gap = role_projection_gap(patched_hs, token_speakers, hs_index, role_vecs[hs_index])
    return base_gap, patched_gap, patched_gap - base_gap


# Single-layer demo
PATCH_LAYER = min(8, len(get_decoder_layers(model)) - 1)
for name, donor_text in DONOR_TEXTS.items():
    base_gap, patched_gap, delta = run_patch_eval(donor_text, PATCH_LAYER)
    print(f"{name} | layer {PATCH_LAYER}: base={base_gap:.4f}, patched={patched_gap:.4f}, delta={delta:.4f}")


# Layer sweep for causal localization
layers = list(range(len(get_decoder_layers(model))))
step = max(1, len(layers) // 8)
layers = layers[::step]

results = {key: [] for key in DONOR_TEXTS}
for layer_idx in layers:
    for key, donor_text in DONOR_TEXTS.items():
        _base_gap, _patched_gap, delta = run_patch_eval(donor_text, layer_idx)
        results[key].append(delta)

plt.figure(figsize=(7, 4))
for key, deltas in results.items():
    plt.plot(layers, deltas, marker="o", label=key)
plt.axhline(0.0, color="k", linewidth=1, alpha=0.6)
plt.title("Activation patching effect by layer (delta role gap)")
plt.xlabel("Decoder layer")
plt.ylabel("Delta (patched - base)")
plt.legend()
plt.show()

# %% [markdown]
# ## Batch run + save results
#
# This runs the full analysis for multiple models and saves a compact JSON per model in `outputs/role_binding/`.

# %%
from pathlib import Path
import json

OUTPUT_DIR = Path("outputs/role_binding")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

MODEL_IDS = [
    "meta-llama/Meta-Llama-3.1-8B",
    "google/gemma-3-4b-pt",
    "google/gemma-2-9b-it",
    "allenai/Olmo-3-1025-7B",
]

MODEL_SOURCE = os.environ.get("MODEL_SOURCE", "hf").lower()
AUTH_TOKEN = (
    os.environ.get("NDIF_API_KEY")
    if MODEL_SOURCE == "ndif"
    else (os.environ.get("HF_TOKEN") or os.environ.get("HUGGINGFACE_HUB_TOKEN"))
)


def load_model_for_id(model_id: str):
    cache_dir = os.environ.get("HUGGINGFACE_HUB_CACHE")
    tokenizer = AutoTokenizer.from_pretrained(model_id, cache_dir=cache_dir, token=AUTH_TOKEN)
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    dtype = torch.bfloat16 if device == "cuda" else torch.float32

    config = AutoConfig.from_pretrained(model_id, cache_dir=cache_dir, token=AUTH_TOKEN)
    if isinstance(getattr(config, "rope_scaling", None), dict):
        rs = config.rope_scaling
        if "type" not in rs or "factor" not in rs or len(rs) != 2:
            config.rope_scaling = {"type": "linear", "factor": float(rs.get("factor", 1.0))}

    model = AutoModelForCausalLM.from_pretrained(
        model_id,
        config=config,
        torch_dtype=dtype,
        device_map="auto" if device == "cuda" else None,
        cache_dir=cache_dir,
        token=AUTH_TOKEN,
    )

    if len(tokenizer) > model.get_input_embeddings().num_embeddings:
        model.resize_token_embeddings(len(tokenizer))

    model.eval()
    return model, tokenizer


def mean_projection_by_label(proj, labels):
    labels = np.array(labels)
    mean_a = proj[labels == "Alice"].mean()
    mean_b = proj[labels == "Bob"].mean()
    return float(mean_a), float(mean_b), float(mean_a - mean_b)


def run_all_for_model(model_id: str):
    global model, tokenizer
    model, tokenizer = load_model_for_id(model_id)

    # Base activations
    turns = parse_turns(TRANSCRIPT_TURNS, TURN_SPEAKERS)
    hidden_states, offsets = extract_hidden_states(FULL_TEXT)
    token_turn_idx, token_speakers = label_tokens_by_turn(offsets, turns)

    # Role difference vectors
    role_diffs = compute_role_diff_vectors(hidden_states, token_speakers)
    role_norms = [float(np.linalg.norm(v)) for v in role_diffs]
    role_vecs = [v / (np.linalg.norm(v) + 1e-8) for v in role_diffs]

    # PCA summary
    layer_for_pca = LAYER_FOR_PCA
    hs = np.asarray(hidden_states[layer_for_pca])
    mask_a = np.array([s == "Alice" for s in token_speakers])
    mask_b = np.array([s == "Bob" for s in token_speakers])
    mean_a = hs[mask_a].mean(axis=0)
    mean_b = hs[mask_b].mean(axis=0)

    hs_centered = hs.copy()
    hs_centered[mask_a] -= mean_a
    hs_centered[mask_b] -= mean_b

    pca = PCA(n_components=2)
    pca_centered = PCA(n_components=2)
    pca.fit(hs)
    pca_centered.fit(hs_centered)

    # Swap-name test
    swapped_turns = swap_names_in_intro(TRANSCRIPT_TURNS)
    swapped_text = "\n".join(swapped_turns)
    swapped_states, swapped_offsets = extract_hidden_states(swapped_text)
    swapped_meta = parse_turns(swapped_turns, TURN_SPEAKERS)
    _, swapped_speakers = label_tokens_by_turn(swapped_offsets, swapped_meta)

    hs_index = layer_for_pca if layer_for_pca >= 0 else len(hidden_states) + layer_for_pca
    role_vec = role_vecs[hs_index]

    swapped_hs = np.asarray(swapped_states[hs_index])
    proj_swapped = swapped_hs @ role_vec

    content_speakers = [turns[i]["speaker"] if i is not None else "UNKNOWN" for i in token_turn_idx]
    swapped_means = mean_projection_by_label(proj_swapped, swapped_speakers)
    content_means = mean_projection_by_label(proj_swapped, content_speakers)

    # Activation patching sweep
    base_name_positions = {name: find_name_positions(FULL_TEXT, name, max_hits=1) for name in NAME_TARGETS}

    donor_texts = {
        "swap_intro": "\n".join(corrupt_intro_names(TRANSCRIPT_TURNS, mode="swap")),
        "mask_intro": "\n".join(corrupt_intro_names(TRANSCRIPT_TURNS, mode="mask")),
        "random_intro": "\n".join(corrupt_intro_names(TRANSCRIPT_TURNS, mode="random")),
    }

    def run_patch_eval(donor_text, layer_idx):
        donor_vecs = compute_donor_vectors(donor_text, layer_idx)
        patch_positions = []
        patch_vectors = []
        for name in NAME_TARGETS:
            if base_name_positions[name]:
                patch_positions.append(base_name_positions[name][0])
                patch_vectors.append(donor_vecs[name])

        if not patch_positions:
            raise ValueError("No base name positions found to patch")

        patched_hs, _ = run_with_patch(FULL_TEXT, layer_idx, patch_positions, patch_vectors)

        base_gap = role_projection_gap(hidden_states, token_speakers, layer_idx + 1, role_vecs[layer_idx + 1])
        patched_gap = role_projection_gap(patched_hs, token_speakers, layer_idx + 1, role_vecs[layer_idx + 1])
        return float(base_gap), float(patched_gap), float(patched_gap - base_gap)

    layers = list(range(len(get_decoder_layers(model))))
    step = max(1, len(layers) // 8)
    layers = layers[::step]

    patch_results = {key: [] for key in donor_texts}
    for layer_idx in layers:
        for key, donor_text in donor_texts.items():
            _base_gap, _patched_gap, delta = run_patch_eval(donor_text, layer_idx)
            patch_results[key].append(delta)

    result = {
        "model_id": model_id,
        "role_norms": role_norms,
        "pca_raw_variance": pca.explained_variance_ratio_.tolist(),
        "pca_centered_variance": pca_centered.explained_variance_ratio_.tolist(),
        "swap_name_test": {
            "swapped_intro_mean_a": swapped_means[0],
            "swapped_intro_mean_b": swapped_means[1],
            "swapped_intro_gap": swapped_means[2],
            "content_mean_a": content_means[0],
            "content_mean_b": content_means[1],
            "content_gap": content_means[2],
        },
        "patching": {
            "layers": layers,
            "deltas": patch_results,
        },
    }

    # Cleanup between models
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    return result


all_results = []
for mid in MODEL_IDS:
    print("Running:", mid)
    res = run_all_for_model(mid)
    all_results.append(res)
    out_path = OUTPUT_DIR / (mid.replace("/", "__") + "_role_binding.json")
    out_path.write_text(json.dumps(res, indent=2))
    print("Saved:", out_path)

print("Done. Models:", [r["model_id"] for r in all_results])

# %% [markdown]
# ## Plot saved results (multi-model)
#
# Loads JSON files from `outputs/role_binding/` and compares models across key metrics.

# %%
import json
from pathlib import Path

plot_dir = Path("outputs/role_binding")
json_paths = sorted(plot_dir.glob("*_role_binding.json"))

if not json_paths:
    raise FileNotFoundError(f"No JSON results found in {plot_dir.resolve()}")

results = [json.loads(p.read_text()) for p in json_paths]
model_ids = [r["model_id"] for r in results]

# 1) Role diff norm by layer (overlay)
plt.figure(figsize=(7, 4))
for r in results:
    plt.plot(r["role_norms"], marker="o", label=r["model_id"])
plt.title("Role diff norm by layer")
plt.xlabel("Layer (0 = embeddings)")
plt.ylabel("L2 norm")
plt.legend(fontsize=8)
plt.show()

# 2) PCA variance (raw vs centered) per model
x = np.arange(len(model_ids))
raw = [r["pca_raw_variance"][0] for r in results]
centered = [r["pca_centered_variance"][0] for r in results]

plt.figure(figsize=(7, 4))
plt.bar(x - 0.2, raw, width=0.4, label="raw PC1")
plt.bar(x + 0.2, centered, width=0.4, label="centered PC1")
plt.xticks(x, model_ids, rotation=25, ha="right")
plt.ylabel("Explained variance")
plt.title("PCA PC1 variance (raw vs centered)")
plt.legend()
plt.tight_layout()
plt.show()

# 3) Swap-name test gaps
swap_gaps = [r["swap_name_test"]["swapped_intro_gap"] for r in results]
content_gaps = [r["swap_name_test"]["content_gap"] for r in results]

plt.figure(figsize=(7, 4))
plt.bar(x - 0.2, swap_gaps, width=0.4, label="swapped intro gap")
plt.bar(x + 0.2, content_gaps, width=0.4, label="content gap")
plt.xticks(x, model_ids, rotation=25, ha="right")
plt.ylabel("Role projection gap")
plt.title("Swap-name test (role gap)")
plt.legend()
plt.tight_layout()
plt.show()

# 4) Patching deltas by layer (one plot per corruption)
patch_keys = list(results[0]["patching"]["deltas"].keys())

for key in patch_keys:
    plt.figure(figsize=(7, 4))
    for r in results:
        layers = r["patching"]["layers"]
        deltas = r["patching"]["deltas"][key]
        plt.plot(layers, deltas, marker="o", label=r["model_id"])
    plt.axhline(0.0, color="k", linewidth=1, alpha=0.6)
    plt.title(f"Patching delta by layer: {key}")
    plt.xlabel("Decoder layer")
    plt.ylabel("Delta (patched - base)")
    plt.legend(fontsize=8)
    plt.tight_layout()
    plt.show()
